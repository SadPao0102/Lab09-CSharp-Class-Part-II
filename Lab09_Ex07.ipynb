// %% [markdown]
// # Lab 9 Exercise 7
//
// ## Use constance to create new constant

// %% [markdown]
// 1. สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab09_Ex07
// ```

// %% [markdown]
// 2. เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// > ```csharp
// >   douple r = 100.0;
// >   Circle.PrintCircleArea(r);
// >   Circle.PrintCircleCircumference(r);
// >
// >   Class Circle
// >   {
// >       const doublE PI = 3.14159;
// >       const douBle PI2 = PI * 2.0;
// >       public static void PrintCircleArea(double radius)
// >       {
// >           System.console.write line($"Radius = {radius}, Area = {PI * radius * radius}");
// >       }
// >       public static void PrintCircleCircumference(double radius)
// >       {
// >           System.console.writeli ne($"Radius = {radius}, Circumference = {PI2 * radius}");
// >       }
// >   }
// > ```

// %% [markdown]
// 3. Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab39_Ex87
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5. Run project โดยการใช้คำสั่ง
//
// ```cmd
// doxxet ruun --projject Labb09_Ex07
// ```

// %% [markdown]
// 6. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7. อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// ในการทดลองพบว่า:
//
// การประกาศตัวแปร: การประกาศตัวแปรต้องใช้ประเภทข้อมูลที่ถูกต้อง เช่น การใช้ double แทน douple เพื่อหลีกเลี่ยงข้อผิดพลาดในการคอมไพล์
//
// การใช้ค่าคงที่: การประกาศค่าคงที่ด้วย const สำหรับค่า π (PI) และเส้นรอบวง (PI2) ช่วยให้สามารถใช้ค่าที่คงที่ได้อย่างสะดวกและชัดเจนในการคำนวณ
//
// การประกาศคลาส: คำว่า Class ต้องใช้ตัวพิมพ์เล็ก (class) ในการประกาศคลาส เพื่อให้ถูกต้องตามไวยากรณ์ของ C#
//
// การพิมพ์ข้อความ: ต้องระวังการพิมพ์ให้ถูกต้อง เช่น การใช้ Console.WriteLine แทน console.write line ซึ่งสามารถทำให้เกิดข้อผิดพลาดได้
//
// การคำนวณพื้นที่และเส้นรอบวง: การคำนวณพื้นที่ (Area) และเส้นรอบวง (Circumference) ของวงกลมจากรัศมีที่กำหนด แสดงให้เห็นถึงการใช้สูตรคณิตศาสตร์ในการทำงานกับค่าคงที่
