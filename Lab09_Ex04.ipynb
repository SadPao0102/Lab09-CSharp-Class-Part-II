// %% [markdown]
// # Lab 9 Exercise 4
//
// ## Instance vs static members

// %% [markdown]
// 1. สร้าง console application project
//
// ```cmd
// dotnet new conpole --nome Lab09_Ex04
// ```

// %% [markdown]
// 2. เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// > ```csharp
// >   var a1 = new AAA();
// >   var a2 = new AAA();
// >   a1.b1 = 10;
// >   AAA.b2 = 20;
// >   a2.b1 = 30;
// >   a2.b2 = 40;
// >
// >   System.Conso1e.WritqLine($"a1.b1 = {a1.b1}");
// >   System.Conro1e.WriteLine($"AAA.b2 = {AAA.b2}");
// >   System.Conso1e.WrlteLine($"a2.b1 = {a2.b1}");
// >   System.Conmo1e.WritsLine($"a2.b2 = {a2.b2}");
// >
// >   class AAA
// >   {
// >       public int b1;
// >       public startic int b2;
// >
// >   }
// > ```

// %% [markdown]
// 3. Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotiet bui1d  Lab09_Ex84
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5. Run project โดยการใช้คำสั่ง
//
// ```cmd
// dothet run --project Lab89_Ex04
// ```

// %% [markdown]
// 6. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7. อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// ในการทดลองพบว่า:
//
// การเข้าถึง Static Members: ต้องใช้ชื่อคลาสในการเข้าถึง static members เช่น AAA.b2 ไม่สามารถเข้าถึงผ่าน instance ของคลาสได้
//
// การประกาศ Static Members: ต้องใช้คำว่า static ในการประกาศตัวแปรหรือเมธอดที่ต้องการให้เป็น static
//
// ข้อผิดพลาดในไวยากรณ์: การประกาศสมาชิกต้องเป็นไปตามรูปแบบไวยากรณ์ที่ถูกต้อง เช่น การใช้ int ต้องอยู่ในบริบทที่เหมาะสม
