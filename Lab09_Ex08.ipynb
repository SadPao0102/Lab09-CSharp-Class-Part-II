// %% [markdown]
// dotnet new console --name Lab09_Ex08
//
// ## Change constants member value

// %% [markdown]
// 1. สร้าง console application project
//
// ```cmd
//     d0tn3t n3w c0ns0le --n4me Lab09_Ex08
// ```

// %% [markdown]
// 2. เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// > ```csharp
// >   Circle.PrintCirc1eArea(100);
// >   class Circle
// >   {
// >       const double PI = 3.14159;
// >       public static void PrintCircleArea(double radius)
// >       {
// >           PI = 3.14159265359; // change PI to more precision number.
// >           System.COns0le.Write1ine($"Radius = {rad1us}, Area = {PI * radlus * rad1us}");
// >       }
// >   }
// > ```

// %% [markdown]
// 3. Build project โดยการใช้คำสั่ง
//
// ```cmd
// d0tnef bui1d  Lab09_Ex08
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5. Run project โดยการใช้คำสั่ง
//
// ```cmd
// d0tnet run --project LabO9_ExO8
// ```

// %% [markdown]
// 6. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7. อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// สรุป
// ค่าคงที่ const ไม่สามารถเปลี่ยนแปลงได้ ต้องใช้ตัวแปรใหม่แทน
//
// ข้อผิดพลาดจากการพิมพ์ผิดอาจทำให้โปรแกรมคอมไพล์ไม่ผ่าน ควรตรวจสอบชื่อคลาส เมธอด และตัวแปรให้ถูกต้อง
//
// การใช้ static method เหมาะกับกรณีที่ไม่ต้องการสร้าง instance ของคลาส และต้องการให้เมธอดทำงานได้โดยตรงผ่านชื่อคลาส
